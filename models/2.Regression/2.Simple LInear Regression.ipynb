# %% [markdown]
# Simple Linear Regression

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /tmp/ipykernel_7991/2151744951.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Import the dataset

# %%
dataset = pd.read_csv("/home/nikhilds/GitHub/machine_learning_for_beginners/datasets/1.Regression/SimpleLInearRegression.csv")
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

# %% [markdown]
# Splitting the dataset into train and test

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train ,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# Training the Simple Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predicting the test set results

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# Visualizing the Training set results

# %%
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train, regressor.predict(X_train) ,color='blue')# Gives the straight line for predicted salaries using X_train
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience(Training Set)')
plt.show()

# %% [markdown]
# Visualizing the Test set results

# %%
plt.scatter(X_test,y_test,color='red')
plt.scatter(X_test, y_pred ,color='blue')# Marks the predicted salaries for the test set
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience(Test Set)')
plt.show()

# %% [markdown]
# Predicting a value

# %%
y_pred1 = regressor.predict([[12]])
print(y_pred1)
# Out:
# [138531.00067138]

# %% [markdown]
# Finding the coefficients and intercept

# %%
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9312.57512673]
# 26780.09915062818
